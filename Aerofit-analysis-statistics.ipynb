# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("aerofit.csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ## Univariate Analysis:

# %%
plt.figure(figsize=(16,4),dpi=100)
plt.subplot(1,3,1)
ax=plt.gca()
sns.histplot(data=df,x="Age",bins=20,color="brown")
plt.xticks(rotation=45)
plt.subplot(1,3,2)
sns.countplot(data=df,x="Education")
plt.subplot(1,3,3)
sns.countplot(data=df,x="Usage")
plt.show()

# %% [markdown]
# 1. People between the age range of 20 to 30 are highly likely to buy the products.
# 2. Customers who have education of 14 to 16 years are highly preferred to buy the products.
# 3. Most of the Customer who buys the products uses it on an average of 3 to 4 times per week.

# %%
plt.figure(figsize=(16,4),dpi=100)
plt.subplot(1,3,1)
ax=plt.gca()
sns.countplot(data=df,x="Fitness")
plt.subplot(1,3,2)
sns.histplot(data=df,x="Income",bins=10,color="green")
plt.subplot(1,3,3)
sns.histplot(data=df,x="Miles",bins=10)
plt.show()

# %% [markdown]
# * Mostly customers with an avearge fitness of 3 tends to buy the products.
# * High volume of people who are buying the products are earning between the range of 4300 to 6000 dollars.
# * Most of those who walk 50 to 130 miles per week, buy the products.

# %%
plt.figure(figsize=(16,4),dpi=100)
plt.subplot(1,3,1)
ax=plt.gca()
sns.countplot(data=df,x="Gender",color="yellow")
plt.subplot(1,3,2)
sns.countplot(data=df,x="MaritalStatus",color="green")
plt.show()

# %% [markdown]
# ## Bivariate Analysis:

# %%
plt.figure(figsize=(16,4),dpi=100)
plt.subplot(1,3,1)
ax=plt.gca()
sns.boxplot(data=df,x="Product",y="Age")
plt.subplot(1,3,2)
sns.boxplot(data=df,x="Product",y="Education")
plt.subplot(1,3,3)
sns.boxplot(data=df,x="Product",y="Usage")
plt.show()

# %% [markdown]
# * The average age of those who are buying the products are most likely between 25 to 27.
# * There are no much impact of education over buying the products.
# * The customer on average uses the treadmill KP281 3 to 4 times, KP481 less than 4 times and for KP781 4 to 5 times per week.

# %%
plt.figure(figsize=(18,4),dpi=100)
plt.subplot(1,3,1)
ax=plt.gca()
sns.boxplot(data=df,x="Product",y="Fitness")
plt.subplot(1,3,2)
sns.boxplot(data=df,x="Product",y="Income")
plt.subplot(1,3,3)
sns.boxplot(data=df,x="Product",y="Miles")
plt.show()

# %% [markdown]
# * The customers who have high fiteness on an average scale of 4 to 5, prefers to buy KP781.
# * Customers who has median income of 8000$ buy KP781
# * Customers who walk/run for 100 to 200 miles per week are expected to buy KP781, and f

# %%
plt.figure(figsize=(18,4),dpi=100)
plt.subplot(1,3,1)
ax=plt.gca()
sns.countplot(data=df,x="Product",hue="Gender")
plt.subplot(1,3,2)
sns.histplot(data=df,x="Product",hue="MaritalStatus")
plt.subplot(1,3,3)
sns.histplot(data=df,x="Age",bins=5,kde=True)
plt.show()

# %% [markdown]
# * For KP281 and KP481, there are no much differences in gender buying the product, whereas, for KP781, mostly males prefer.
# * Also, people who are single has more ineterest in buying the products than married ones.
# * People who are between the range 25 to 30 are highly likely to buy products.

# %% [markdown]
# ## Multivariate Analysis

# %%
fig = plt.figure(figsize = (16, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(data=df,xs="Usage", ys="Miles",zs="Income")
ax.set_xlabel("Usage")
ax.set_ylabel("Miles")
ax.set_zlabel("Income", rotation = 90);

# %% [markdown]
# From the above graph, it is clear that the more the customer walks in miles, the more the usage of the product.

# %%
fig = plt.figure(figsize = (16, 8))
sns.scatterplot(data=df,x="Income", y="Age",hue="Product",palette="Spectral")
ax.set_xlabel("Usage")
ax.set_ylabel("Income")
# Out:
# Text(0.06297146794096585, 0.5, 'Income')

# %% [markdown]
# * People with high income and an average age of range 23 to 35 mostly prefers to buy the product KP781
# * People with the income range of 3000 to 6000 dollars in all age ranges buys products KP281 and KP481 in similar distribution

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
fig = plt.figure(figsize = (16, 4))
plt.subplot(1,3,1)
pivotl=df.pivot_table(index="Product",columns="MaritalStatus",values="Income")
sns.heatmap(pivotl)
plt.subplot(1,3,2)
pivotl=df.pivot_table(index="Product",columns="Fitness",values="Income")
sns.heatmap(pivotl)
plt.subplot(1,3,3)
pivotl=df.pivot_table(index="Product",columns="Gender",values="Income")
sns.heatmap(pivotl)
# sns.histplot(data=df,x="Income",y="Product",hue="MaritalStatus",palette="mako")
# Out:
# <Axes: xlabel='Gender', ylabel='Product'>

# %% [markdown]
# From the graph above, it is clear that

# %%
fig = plt.figure(figsize = (16, 4))
plt.subplot(1,3,1)
pivotl=df.pivot_table(index="Product",columns="Education",values="Income")
sns.heatmap(pivotl)
plt.subplot(1,3,2)
pivotl=df.pivot_table(index="Product",columns="Usage",values="Income")
sns.heatmap(pivotl)
plt.subplot(1,3,3)
pivotl=df.pivot_table(index="Product",columns="Miles",values="Income")
sns.heatmap(pivotl)
# Out:
# <Axes: xlabel='Miles', ylabel='Product'>

# %%
fig = plt.figure(figsize = (16, 4))
plt.subplot(1,3,1)
pivotl=df.pivot_table(index="Product",columns="MaritalStatus",values="Age")
sns.heatmap(pivotl)
plt.subplot(1,3,2)
pivotl=df.pivot_table(index="Product",columns="Fitness",values="Age")
sns.heatmap(pivotl)
plt.subplot(1,3,3)
pivotl=df.pivot_table(index="Product",columns="Gender",values="Age")
sns.heatmap(pivotl)
# Out:
# <Axes: xlabel='Gender', ylabel='Product'>

# %%
fig = plt.figure(figsize = (16, 4))
plt.subplot(1,3,1)
pivotl=df.pivot_table(index="Product",columns="Education",values="Age")
sns.heatmap(pivotl)
plt.subplot(1,3,2)
pivotl=df.pivot_table(index="Product",columns="Usage",values="Age")
sns.heatmap(pivotl)
plt.subplot(1,3,3)
pivotl=df.pivot_table(index="Product",columns="Miles",values="Age")
sns.heatmap(pivotl)
# Out:
# <Axes: xlabel='Miles', ylabel='Product'>

# %% [markdown]
# ## Marginal Probability of Product Purchased

# %%
pd.crosstab(df.Product,len(df)).apply(lambda x: x/len(df)*100)
# Out:
# col_0          180
# Product
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222

# %%
df["Product"].value_counts(normalize=True)*100
# Out:
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: Product, dtype: float64

# %% [markdown]
# ## Conditional Probability

# %%
df['Gender'].where(df['Product']=='KP281').value_counts(normalize=True)
# Out:
# Male      0.5
# Female    0.5
# Name: Gender, dtype: float64

# %%
df['Gender'].where(df['Product']=='KP481').value_counts(normalize=True)
# Out:
# Male      0.516667
# Female    0.483333
# Name: Gender, dtype: float64

# %%
df['Gender'].where(df['Product']=='KP781').value_counts(normalize=True)
# Out:
# Male      0.825
# Female    0.175
# Name: Gender, dtype: float64

# %%
temp = df['Product'].unique()

# to get probability of each gender for the given product

for i in range(len(temp)):
  y = df['Gender'].where(df['Product']==temp[i]).value_counts(normalize=True)
  print('PROBABILITY OF EACH GENDER FOR THE PRODUCT',temp[i])
  print(y)
# Out:
# PROBABILITY OF EACH GENDER FOR THE PRODUCT KP281
# Male      0.5
# Female    0.5
# Name: Gender, dtype: float64
# PROBABILITY OF EACH GENDER FOR THE PRODUCT KP481
# Male      0.516667
# Female    0.483333
# Name: Gender, dtype: float64
# PROBABILITY OF EACH GENDER FOR THE PRODUCT KP781
# Male      0.825
# Female    0.175
# Name: Gender, dtype: float64

# %% [markdown]
# INFERENCE:
# KP281 and KP481 - almost equal contribution by both gender KP781 - Male users dominate female with 82.5%

# %%
temp = df['Product'].unique()

# to get probability of each MaritalStatus for the given product

for i in range(len(temp)):
  y = df['MaritalStatus'].where(df['Product']==temp[i]).value_counts(normalize=True)
  print('PROBABILITY OF EACH MARITAL STATUS FOR THE PRODUCT',temp[i])
  print(y)
# Out:
# PROBABILITY OF EACH MARITAL STATUS FOR THE PRODUCT KP281
# Partnered    0.6
# Single       0.4
# Name: MaritalStatus, dtype: float64
# PROBABILITY OF EACH MARITAL STATUS FOR THE PRODUCT KP481
# Partnered    0.6
# Single       0.4
# Name: MaritalStatus, dtype: float64
# PROBABILITY OF EACH MARITAL STATUS FOR THE PRODUCT KP781
# Partnered    0.575
# Single       0.425
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# ### INFERENCE:
# **Partnered** users are more compared to single users for all product category

# %% [markdown]
# ## IMPACT OF INCOME ON THE PRODUCT TYPE

# %%
avg_income = df['Income'].where(df['Product']=='KP281').mean()

avg_income
# Out:
# 46418.025

# %%
temp = df['Product'].unique()

# to get the average income of users of the given product

for i in range(len(temp)):
  avg_income = df['Income'].where(df['Product']==temp[i]).mean()
  print('AVERAGE INCOME OF USERS OF THE PRODUCT',temp[i])
  print(avg_income)
# Out:
# AVERAGE INCOME OF USERS OF THE PRODUCT KP281
# 46418.025
# AVERAGE INCOME OF USERS OF THE PRODUCT KP481
# 48973.65
# AVERAGE INCOME OF USERS OF THE PRODUCT KP781
# 75441.575

# %% [markdown]
# ### INFERENCE:
# KP281 and KP481 - Preferred by Mid-level income group.
# **KP781** - Preferred by **High**-level **income** group

# %% [markdown]
# ### AGE VS PRODUCT

# %%
temp = df['Product'].unique()

# to get the average age of users of the given product

for i in range(len(temp)):
  avg_age = df['Age'].where(df['Product']==temp[i]).mean()
  print('AVERAGE AGE OF USERS OF THE PRODUCT',temp[i])
  print(avg_age)
# Out:
# AVERAGE AGE OF USERS OF THE PRODUCT KP281
# 28.55
# AVERAGE AGE OF USERS OF THE PRODUCT KP481
# 28.9
# AVERAGE AGE OF USERS OF THE PRODUCT KP781
# 29.1

# %% [markdown]
# ### INFERENCE:
# Users of these Product are almost of the same age group of around **30 years** with some outliers.

# %% [markdown]
# ### FITNESS PERCENT OF EACH GENDER FOR THE GIVEN PRODUCT

# %%
temp = df['Product'].unique()
temp_gender = df['Gender'].unique()

# to get fitness percent of each gender for the given product

for i in range(len(temp)):
  for j in range(len(temp_gender)):
    y = df['Fitness'].where((df['Product']==temp[i])&(df['Gender']== temp_gender[j])).value_counts(normalize=True)
    print('FITNESS PERCENTAGE OF ',temp_gender[j],' FOR THE PRODUCT',temp[i])
    print(y)
# Out:
# FITNESS PERCENTAGE OF  Male  FOR THE PRODUCT KP281
# 3.0    0.700
# 4.0    0.150
# 2.0    0.100
# 1.0    0.025
# 5.0    0.025
# Name: Fitness, dtype: float64
# FITNESS PERCENTAGE OF  Female  FOR THE PRODUCT KP281
# 3.0    0.650
# 2.0    0.250
# 4.0    0.075
# 5.0    0.025
# Name: Fitness, dtype: float64
# FITNESS PERCENTAGE OF  Male  FOR THE PRODUCT KP481
# 3.0    0.677419
# 2.0    0.193548
# 4.0    0.129032
# Name: Fitness, dtype: float64
# FITNESS PERCENTAGE OF  Female  FOR THE PRODUCT KP481
# 3.0    0.620690
# 2.0    0.206897
# 4.0    0.137931
# 1.0    0.034483
# Name: Fitness, dtype: float64
# FITNESS PERCENTAGE OF  Male  FOR THE PRODUCT KP781
# 5.0    0.727273
# 4.0    0.181818
# 3.0    0.090909
# Name: Fitness, dtype: float64
# FITNESS PERCENTAGE OF  Female  FOR THE PRODUCT KP781
# 5.0    0.714286
# 4.0    0.142857
# 3.0    0.142857
# Name: Fitness, dtype: float64

# %% [markdown]
# ### INFERENCE:
# Irrespective of Gender, the Users of **KP781** are more **fit** with around **72%** of users comes under fitness band **5**

# %%
avg_income = df['Income'].mean()
df['Product'].where((df['Gender']=='Male')&(df['Income']>=avg_income)).value_counts(normalize=True)
# Out:
# KP781    0.613636
# KP281    0.227273
# KP481    0.159091
# Name: Product, dtype: float64

# %%
avg_income = df['Income'].mean()
df['Product'].where((df['Gender']=='Female')&(df['Income']>=avg_income)).value_counts(normalize=True)
# Out:
# KP281    0.421053
# KP481    0.315789
# KP781    0.263158
# Name: Product, dtype: float64

# %% [markdown]
# ### BUSINESS INSIGHTS:
# 1. **PRODUCT:**
#       1. 3 unique products - KP281, KP481, KP781
#       2. **KP281** most **preferred** with overall contribution of 44%
# 2. **AGE:**
#       1. Age group varies from 18 years to 50 years
#       2. Most people belong to the age group of **25 years**
#       3. KP781 users have most outliers when age is considered
# 3. **MARITAL STATUS:**
#       1. **Partnered/Married** users are more than that of unmarried users
#       2. Partnered users contribute **59%** of the total
# 4. **GENDER:**
#       1. **Male** users dominate female users
#       2. Male - 57%, Female - 42%
# 5. **USAGE:**
#       1. KP281, KP481 - average usage is thrice a week
#       2. **KP781** - average usage is **4 times** a week
# 6. **EDUCATION:**
#       1. KP281, KP481 - average education of the users is 16 years
#       2. KP781 - average education of the users is 18 year

# %% [markdown]
# ### OBSERVATION:
#   People with,
#   1. higher education,
#   2. more income,
#   3. tend to use treadmill more than 4 times a week,
#   4. walk more than 100 miles a week,
#   5. and are more fit
#
# prefer using **KP781**

# %% [markdown]
# ### RECOMMENDATIONS:
# 1. KP281, KP481 - most suited for mid-level income group.
# 2. **KP781** - marketed among **premium** customers.
# 3. KP781 - Most suited for more fit persons who use treadmill almost 5 to 7 days a week and walk more than 100 miles which means its suited for a **sporty** persons and **fitness** **freak**.
# 4. Survey is recommended for income group **below 40,000** to get a wider graph.
# 5. Promote Products among **Single** (Marital status) with **workshops** and **free trials**.
# 6. Encourage **Female** users - emphasize on the **importance** of **fitness**.
